# %%
import matplotlib.pyplot as plt
import numpy as np
import math
from scipy import stats

# %%
x = np.linspace(0, 20, 100)
plt.title('2 Gaussians')
plt.xlabel('Height')
plt.ylabel('p(x)')
plt.plot(x, stats.norm.pdf(x, 5, 1))
plt.plot(x, stats.norm.pdf(x, 15, 1))
plt.show()

# %%
# Option 1 Interpolate distributions

def h(t):
    return (1-t)*stats.norm.pdf(x, 5, 1) + t*stats.norm.pdf(x, 15, 1)

t = 0.5
x = np.linspace(0, 20, 100)
plt.title('2 Gaussians Linearly Interpolated')
plt.xlabel('Height')
plt.ylabel('p(x)')
plt.plot(x, h(t))
plt.ylim(0, 0.4)
plt.show()

# %%
# Option 2 Interpolate params
x = np.linspace(0, 20, 100)
plt.title('2 Gaussians Params Interpolated')
plt.xlabel('Height')
plt.ylabel('p(x)')
plt.plot(x, (stats.norm.pdf(x, (5 + 15) / 2,  math.sqrt((1*1 + 1*1)/2))))
plt.show()

# %%
x1 = np.linspace(2, 8, 25)
x2 = np.linspace(12, 18, 25)
y1 = stats.norm.pdf(x1, 5, 1)
y2 = stats.norm.pdf(x2, 15, 1)

plt.title('2 Gaussians ')
plt.scatter(x1, y1)
plt.scatter(x2, y2)
plt.show()

# %%
# distance
def d(x, xi):
    return x - xi

# G
def G_K(sigma, x):
    return np.exp(-pow(np.linalg.norm(x), 2)/(2*sigma*sigma))


SIGMA = 0.5

# create G-matrix
def create_G(x):
    N = len(x)
    G = np.zeros((N,N))
    sigmas = [SIGMA]*N
    for i in range(N):
        for j in range(N):
            G[i,j] = G_K(sigmas[i], d(x[i], x[j]))
        #G[i, :] /= G[i, :].sum()
    return G

# Solve the lsq 
from scipy import optimize
def get_weight(x, y):
    G = create_G(x)
    (w, _) = optimize.nnls(G, y)
    curr_loss = y - np.dot(G,w)
    print("w: ", w)
    print('loss: ', np.linalg.norm(curr_loss))
    
    plt.figure()
    plt.scatter(x, y)
    plt.plot(x, G*w)
    plt.scatter(x, np.dot(G, w))
    return w, G

w1, G1 = get_weight(x1, y1)
s1 = w1.sum()
w1 /= s1
w2, G2 = get_weight(x2, y2)
s2 = w2.sum()
w2 /= s2
# now the normalized weights are
# Out:
# w:  [0.00061758 0.         0.00161772 0.00434791 0.00266849 0.01912243
#  0.00919703 0.04806537 0.02738617 0.08654999 0.05160847 0.11605739
#  0.06337365 0.11605739 0.05160847 0.08654999 0.02738617 0.04806537
#  0.00919703 0.01912243 0.00266849 0.00434791 0.00161772 0.
#  0.00061758]
# loss:  1.6363662402341915e-08
# w:  [0.00061758 0.         0.00161772 0.00434791 0.00266849 0.01912243
#  0.00919703 0.04806537 0.02738617 0.08654999 0.05160847 0.11605739
#  0.06337365 0.11605739 0.05160847 0.08654999 0.02738617 0.04806537
#  0.00919703 0.01912243 0.00266849 0.00434791 0.00161772 0.
#  0.00061758]
# loss:  1.6363662402341915e-08

# %%
x_sin = np.linspace(0, 4*math.pi, 40)
y_sin = np.sin(x_sin) + 1
get_weight(x_sin, y_sin)
print('f')
# Out:
# w:  [0.65937681 0.         0.48357229 0.79805908 0.         1.10981852
#  0.1584174  0.53614896 0.64375404 0.         0.43636698 0.13669336
#  0.         0.         0.         0.         0.         0.
#  0.03859427 0.49382646 0.         0.45007182 0.76363456 0.
#  1.04164677 0.2500063  0.60417499 0.40008655 0.53072548 0.
#  0.44851457 0.         0.         0.         0.         0.
#  0.         0.         0.         0.93733905]
# loss:  0.11471239268197225
# f

# %%
# Since solvers are faster when

# %%
from __future__ import print_function
from ortools.graph import pywrapgraph


C = 1e5

G = nx.DiGraph()
G.add_node('s', demand = -1*C)
G.add_node('t', demand =  1*C)

for i in range(len(w1)):
    c = w1[i]*C
    print('capacity: {}'.format(c))
    G.add_edge('s', 'f{}'.format(i), capacity=c)
for j in range(len(w2)):
    c = w2[i]*C
    print('capacity: {}'.format(c))
    G.add_edge('g{}'.format(j), 't', capacity=c)

# we use euclidian distance between distributions. Geodesic distance would be better? 
n1 = len(x1)
n2 = len(x2)
for i in range(n1):
    yi = y1[i]
    for j in range(n2):
        yj = y2[j]
        d = yi - yj
        w = np.dot(d.T, d)*C
        print('Weight: {}'.format(w))
        G.add_edge('f{}'.format(i), 'g{}'.format(j), weight=w)
        
flowCost, flowDict = nx.network_simplex(G)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-140-5e1d7edc5105> in <module>()
#       1 from __future__ import print_function
# ----> 2 from ortools.graph import pywrapgraph
#       3
#       4
#       5 C = 1e5
#
# ModuleNotFoundError: No module named 'ortools'

# %%
from pyemd import emd_with_flow

n = len(x1)

d1 = np.zeros((n,n))
for i in range(n):
    xi = x1[i]
    for j in range(n):
        d1[i,j] = np.power(xi - x2[j], 2)


val, t_matrix = emd_with_flow(w1.astype(np.float64), w2.astype(np.float64), d1)    
print(val)

t_matrix = np.array(t_matrix)

# %%
# Interpolation

# 1) for each matching create a particle on source and target side
#  those particles have then obviously the same weight
# 2) then for each matching we create a new gaussian with the weight of the matching
# 3) z_l is then the geodistic interpolation between source and target 
# and we can calculate the new position with this 

N, M = t_matrix.shape            
particle_config = []
for i in range(N):
    for j in range(M):
        if t_matrix[i,j] != 0:
            particle_config.append((i,j,t_matrix[i,j]))
particle_config

# %%
SIGMA = 0.5

w_l = [w for (i,j,w) in particle_config]

# create G-matrix
def create_G(x, t):
    N = len(x)
    G = np.zeros((N,len(w_l)))
    sigmas = [SIGMA]*N
    for l,(u,v,w) in enumerate(particle_config):
        for i in range(N):
            z_l = (1-t)*x[u] + t*x[v]
            G[i,l] = G_K(sigmas[l], d(z_l, x[i]))
        #G[i, :] /= G[i, :].sum()
    return G

def h(t):
    z = (1-t)*x1 + t*x2
    sf = (1-t)*s1 + t*s2
    G = create_G(z, t)
    
    #plt.figure()
    #plt.plot(x1, y1)
    #plt.plot(x2, y2)
    #plt.plot(z, sf*G*w_l)
    #plt.scatter(z, np.dot(sf*G, w_l))
    #plt.show()
    return z, sf*G*w_l, np.dot(sf*G, w_l)
    
z, gaussians, interpol  = h(0.7)

plt.figure()
plt.plot(x1, y1)
plt.plot(x2, y2)
plt.plot(z, gaussians)
plt.scatter(z, interpol)
plt.show()

# %%
plt.figure()
for i in range(gaussians.T.shape[0]):
    plt.plot(z, gaussians.T[i])
plt.show()

# %%
# Out:
# (array([ 9.  ,  9.25,  9.5 ,  9.75, 10.  , 10.25, 10.5 , 10.75, 11.  ,
#         11.25, 11.5 , 11.75, 12.  , 12.25, 12.5 , 12.75, 13.  , 13.25,
#         13.5 , 13.75, 14.  , 14.25, 14.5 , 14.75, 15.  ]),
#  array([[9.00000000e+00, 4.43215060e-03],
#         [9.25000000e+00, 9.09409177e-03],
#         [9.50000000e+00, 1.75290017e-02],
#         [9.75000000e+00, 3.17403618e-02],
#         [1.00000000e+01, 5.39915048e-02],
#         [1.02500000e+01, 8.62776449e-02],
#         [1.05000000e+01, 1.29517784e-01],
#         [1.07500000e+01, 1.82649252e-01],
#         [1.10000000e+01, 2.41970877e-01],
#         [1.12500000e+01, 3.01137555e-01],
#         [1.15000000e+01, 3.52065386e-01],
#         [1.17500000e+01, 3.86668148e-01],
#         [1.20000000e+01, 3.98942292e-01],
#         [1.22500000e+01, 3.86668148e-01],
#         [1.25000000e+01, 3.52065386e-01],
#         [1.27500000e+01, 3.01137555e-01],
#         [1.30000000e+01, 2.41970877e-01],
#         [1.32500000e+01, 1.82649252e-01],
#         [1.35000000e+01, 1.29517784e-01],
#         [1.37500000e+01, 8.62776449e-02],
#         [1.40000000e+01, 5.39915048e-02],
#         [1.42500000e+01, 3.17403618e-02],
#         [1.45000000e+01, 1.75290017e-02],
#         [1.47500000e+01, 9.09409177e-03],
#         [1.50000000e+01, 4.43215060e-03]]))

# %%
## Animation for interpolating 2 gaussians
from matplotlib import animation, rc
from IPython.display import HTML, Image

rc('animation', html='html5')

# First set up the figure, the axis, and the plot element we want to animate
fig, ax = plt.subplots()

ax.plot(x1, y1)
ax.plot(x2, y2)

gs = 23

lines = [(ax.plot([], [], lw=2)[0]) for i in range(gs)]
lines.append(ax.scatter([],[]))


# initialization function: plot the background of each frame
def init():
    [line.set_data([], []) for line in lines[:-2]]
    
    return lines

# animation function. This is called sequentially
def animate(i):
    t = i/100
    
    z, gaussians, interpol  = h(t)
    
    for i in range(gs):
        lines[i].set_data(z, gaussians.T[i])
    
    off = np.array((z, interpol)).T
    lines[-1].set_offsets(off)
    
    return lines

# call the animator. blit=True means only re-draw the parts that 
# have changed.
anim = animation.FuncAnimation(fig, animate, init_func=init,
                               frames=100, interval=20, blit=True)

# %%
anim.save('animation_ip2.gif', writer='imagemagick', fps=60)

# %%
import imageio
import skimage
im1 = imageio.imread('ocean_day.jpg')
im2 = imageio.imread('ocean_sunset.jpg')

# 1) Calculate color appearance 
im1_lab = skimage.color.rgb2lab(im1)
im2_lab = skimage.color.rgb2lab(im2)

# 2) Reducing bit size
# lets ignore this for now

# 3) Indexing colours and calculate histograms
from sklearn.cluster import MiniBatchKMeans
from sklearn.metrics import pairwise_distances_argmin
from sklearn.datasets import load_sample_image
from sklearn.utils import shuffle

N = 4000

def recreate_image(codebook, labels, w, h):
    """Recreate the (compressed) image from the code book & labels"""
    d = codebook.shape[1]
    image = np.zeros((w, h, d))
    label_idx = 0
    for i in range(w):
        for j in range(h):
            image[i][j] = codebook[labels[label_idx]]
            label_idx += 1
    
    return image

def cluster(im):
    n_colors = N
    N_SAMPLES = -1
    w, h, d = im.shape
    image_array = np.reshape(im, (w * h, d))
    #image_array_sample = shuffle(image_array, random_state=0)
    kmeans = MiniBatchKMeans(n_clusters=n_colors, random_state=0, verbose=True).fit(image_array)
    # Get labels for all points
    labels = kmeans.predict(image_array)

    re_img = recreate_image(kmeans.cluster_centers_, labels, w, h)
    
    plt.figure(2)
    plt.clf()
    plt.axis('off')
    plt.title('Quantized image ({} colors, K-Means)'.format(N))
    plt.imshow(skimage.color.lab2rgb(re_img))
    plt.show()
    return labels, labels.reshape(w, h), kmeans.cluster_centers_

lbl1, lbl_img_1, cookbook1 = cluster(im1_lab)
lbl2, lbl_img_2, cookbook2 = cluster(im2_lab)
# Out:
# Init 1/3 with method: k-means++
# /home/simi/anaconda3/lib/python3.7/site-packages/sklearn/cluster/k_means_.py:1559: RuntimeWarning: init_size=300 should be larger than k=4000. Setting it to 3*k
#   init_size=init_size)
# Inertia for init 1/3: 0.704498
# Init 2/3 with method: k-means++
# /home/simi/anaconda3/lib/python3.7/site-packages/sklearn/cluster/k_means_.py:1559: RuntimeWarning: init_size=300 should be larger than k=4000. Setting it to 3*k
#   init_size=init_size)
# Inertia for init 2/3: 1.185772
# Init 3/3 with method: k-means++
# /home/simi/anaconda3/lib/python3.7/site-packages/sklearn/cluster/k_means_.py:1559: RuntimeWarning: init_size=300 should be larger than k=4000. Setting it to 3*k
#   init_size=init_size)
# Inertia for init 3/3: 1.426602
# Minibatch iteration 1/669000: mean batch inertia: 0.293767, ewa inertia: 0.293767
# Minibatch iteration 2/669000: mean batch inertia: 0.589899, ewa inertia: 0.293856
# Minibatch iteration 3/669000: mean batch inertia: 0.256234, ewa inertia: 0.293845
# Minibatch iteration 4/669000: mean batch inertia: 0.167878, ewa inertia: 0.293807
# Minibatch iteration 5/669000: mean batch inertia: 0.228633, ewa inertia: 0.293788
# Minibatch iteration 6/669000: mean batch inertia: 0.164325, ewa inertia: 0.293749
# Minibatch iteration 7/669000: mean batch inertia: 0.191153, ewa inertia: 0.293718
# Minibatch iteration 8/669000: mean batch inertia: 0.237472, ewa inertia: 0.293701
# Minibatch iteration 9/669000: mean batch inertia: 0.258706, ewa inertia: 0.293691
# [MiniBatchKMeans] Reassigning 50 cluster centers.
# Minibatch iteration 10/669000: mean batch inertia: 0.196436, ewa inertia: 0.293662
# Minibatch iteration 11/669000: mean batch inertia: 0.251927, ewa inertia: 0.293649
# Minibatch iteration 12/669000: mean batch inertia: 0.307485, ewa inertia: 0.293654
# Minibatch iteration 13/669000: mean batch inertia: 0.211840, ewa inertia: 0.293629
# Minibatch iteration 14/669000: mean batch inertia: 0.158278, ewa inertia: 0.293589
# Minibatch iteration 15/669000: mean batch inertia: 0.236579, ewa inertia: 0.293572
# Minibatch iteration 16/669000: mean batch inertia: 0.200130, ewa inertia: 0.293544
# Minibatch iteration 17/669000: mean batch inertia: 0.179369, ewa inertia: 0.293510
# Minibatch iteration 18/669000: mean batch inertia: 0.230499, ewa inertia: 0.293491
# Minibatch iteration 19/669000: mean batch inertia: 0.345140, ewa inertia: 0.293506
# [MiniBatchKMeans] Reassigning 50 cluster centers.
# Minibatch iteration 20/669000: mean batch inertia: 0.210356, ewa inertia: 0.293481
# Minibatch iteration 21/669000: mean batch inertia: 0.203063, ewa inertia: 0.293454
# Minibatch iteration 22/669000: mean batch inertia: 0.209711, ewa inertia: 0.293429
# Minibatch iteration 23/669000: mean batch inertia: 0.217541, ewa inertia: 0.293407
# Minibatch iteration 24/669000: mean batch inertia: 0.269002, ewa inertia: 0.293399
# Minibatch iteration 25/669000: mean batch inertia: 0.253949, ewa inertia: 0.293387
# Minibatch iteration 26/669000: mean batch inertia: 0.173662, ewa inertia: 0.293352
# Minibatch iteration 27/669000: mean batch inertia: 0.237664, ewa inertia: 0.293335
# Minibatch iteration 28/669000: mean batch inertia: 0.267705, ewa inertia: 0.293327
# Minibatch iteration 29/669000: mean batch inertia: 0.232425, ewa inertia: 0.293309
# [MiniBatchKMeans] Reassigning 50 cluster centers.
# Minibatch iteration 30/669000: mean batch inertia: 0.198686, ewa inertia: 0.293281
# Minibatch iteration 31/669000: mean batch inertia: 0.207574, ewa inertia: 0.293255
# Minibatch iteration 32/669000: mean batch inertia: 0.200633, ewa inertia: 0.293228
# Minibatch iteration 33/669000: mean batch inertia: 0.282930, ewa inertia: 0.293224
# Minibatch iteration 34/669000: mean batch inertia: 0.183079, ewa inertia: 0.293192
# Minibatch iteration 35/669000: mean batch inertia: 0.268002, ewa inertia: 0.293184
# Minibatch iteration 36/669000: mean batch inertia: 0.184204, ewa inertia: 0.293151
# Minibatch iteration 37/669000: mean batch inertia: 0.208871, ewa inertia: 0.293126
# Minibatch iteration 38/669000: mean batch inertia: 0.324186, ewa inertia: 0.293135
# Minibatch iteration 39/669000: mean batch inertia: 0.238499, ewa inertia: 0.293119
# [MiniBatchKMeans] Reassigning 50 cluster centers.
# Minibatch iteration 40/669000: mean batch inertia: 0.300368, ewa inertia: 0.293121
# Minibatch iteration 41/669000: mean batch inertia: 0.216183, ewa inertia: 0.293098
# Minibatch iteration 42/669000: mean batch inertia: 0.223131, ewa inertia: 0.293077
# Minibatch iteration 43/669000: mean batch inertia: 0.205677, ewa inertia: 0.293051
# Minibatch iteration 44/669000: mean batch inertia: 0.251611, ewa inertia: 0.293039
# Minibatch iteration 45/669000: mean batch inertia: 0.187168, ewa inertia: 0.293007
# Minibatch iteration 46/669000: mean batch inertia: 0.216931, ewa inertia: 0.292984
# Minibatch iteration 47/669000: mean batch inertia: 0.204078, ewa inertia: 0.292958
# Minibatch iteration 48/669000: mean batch inertia: 0.201620, ewa inertia: 0.292931
# Minibatch iteration 49/669000: mean batch inertia: 0.183750, ewa inertia: 0.292898
# [MiniBatchKMeans] Reassigning 50 cluster centers.
# Minibatch iteration 50/669000: mean batch inertia: 0.205294, ewa inertia: 0.292872
# Minibatch iteration 51/669000: mean batch inertia: 0.146384, ewa inertia: 0.292828
# Minibatch iteration 52/669000: mean batch inertia: 0.298167, ewa inertia: 0.292830
# Minibatch iteration 53/669000: mean batch inertia: 0.171086, ewa inertia: 0.292793
# Minibatch iteration 54/669000: mean batch inertia: 0.169158, ewa inertia: 0.292756
# Minibatch iteration 55/669000: mean batch inertia: 0.211451, ewa inertia: 0.292732
# Minibatch iteration 56/669000: mean batch inertia: 0.233444, ewa inertia: 0.292714
# Minibatch iteration 57/669000: mean batch inertia: 0.249647, ewa inertia: 0.292701
# Minibatch iteration 58/669000: mean batch inertia: 0.417447, ewa inertia: 0.292739
# Minibatch iteration 59/669000: mean batch inertia: 0.229759, ewa inertia: 0.292720
# [MiniBatchKMeans] Reassigning 50 cluster centers.
# Minibatch iteration 60/669000: mean batch inertia: 0.145128, ewa inertia: 0.292676
# Minibatch iteration 61/669000: mean batch inertia: 0.198219, ewa inertia: 0.292647
# Minibatch iteration 62/669000: mean batch inertia: 0.191041, ewa inertia: 0.292617
# Minibatch iteration 63/669000: mean batch inertia: 0.184007, ewa inertia: 0.292585
# Minibatch iteration 64/669000: mean batch inertia: 0.237207, ewa inertia: 0.292568
# Minibatch iteration 65/669000: mean batch inertia: 0.324096, ewa inertia: 0.292577
# Minibatch iteration 66/669000: mean batch inertia: 0.197416, ewa inertia: 0.292549
# Minibatch iteration 67/669000: mean batch inertia: 0.173442, ewa inertia: 0.292513
# Minibatch iteration 68/669000: mean batch inertia: 0.361524, ewa inertia: 0.292534
# Minibatch iteration 69/669000: mean batch inertia: 0.265143, ewa inertia: 0.292526
# [MiniBatchKMeans] Reassigning 50 cluster centers.
# Minibatch iteration 70/669000: mean batch inertia: 0.203855, ewa inertia: 0.292499
# Minibatch iteration 71/669000: mean batch inertia: 0.181964, ewa inertia: 0.292466
# Minibatch iteration 72/669000: mean batch inertia: 0.428225, ewa inertia: 0.292507
# Minibatch iteration 73/669000: mean batch inertia: 0.174683, ewa inertia: 0.292472
# Minibatch iteration 74/669000: mean batch inertia: 0.166618, ewa inertia: 0.292434
# Minibatch iteration 75/669000: mean batch inertia: 0.162206, ewa inertia: 0.292395
# Minibatch iteration 76/669000: mean batch inertia: 0.243289, ewa inertia: 0.292380
# Minibatch iteration 77/669000: mean batch inertia: 0.210464, ewa inertia: 0.292356
# Minibatch iteration 78/669000: mean batch inertia: 0.166976, ewa inertia: 0.292318
# Minibatch iteration 79/669000: mean batch inertia: 0.308125, ewa inertia: 0.292323
# [MiniBatchKMeans] Reassigning 50 cluster centers.
# Minibatch iteration 80/669000: mean batch inertia: 0.207940, ewa inertia: 0.292298
# Minibatch iteration 81/669000: mean batch inertia: 0.177048, ewa inertia: 0.292263
# Minibatch iteration 82/669000: mean batch inertia: 0.235799, ewa inertia: 0.292247
# Minibatch iteration 83/669000: mean batch inertia: 0.171191, ewa inertia: 0.292210
# Minibatch iteration 84/669000: mean batch inertia: 0.223755, ewa inertia: 0.292190
# Minibatch iteration 85/669000: mean batch inertia: 0.206128, ewa inertia: 0.292164
# Minibatch iteration 86/669000: mean batch inertia: 0.234911, ewa inertia: 0.292147
# Minibatch iteration 87/669000: mean batch inertia: 0.190804, ewa inertia: 0.292117
# Minibatch iteration 88/669000: mean batch inertia: 0.140017, ewa inertia: 0.292071
# Minibatch iteration 89/669000: mean batch inertia: 0.180354, ewa inertia: 0.292038
# [MiniBatchKMeans] Reassigning 50 cluster centers.
# Minibatch iteration 90/669000: mean batch inertia: 0.282772, ewa inertia: 0.292035
# Minibatch iteration 91/669000: mean batch inertia: 0.191084, ewa inertia: 0.292005
# Minibatch iteration 92/669000: mean batch inertia: 0.168785, ewa inertia: 0.291968
# Minibatch iteration 93/669000: mean batch inertia: 0.286323, ewa inertia: 0.291966
# Minibatch iteration 94/669000: mean batch inertia: 0.276109, ewa inertia: 0.291962
# Minibatch iteration 95/669000: mean batch inertia: 0.300458, ewa inertia: 0.291964
# Minibatch iteration 96/669000: mean batch inertia: 0.206002, ewa inertia: 0.291939
# Minibatch iteration 97/669000: mean batch inertia: 0.179498, ewa inertia: 0.291905
# Minibatch iteration 98/669000: mean batch inertia: 0.130108, ewa inertia: 0.291857
# Minibatch iteration 99/669000: mean batch inertia: 0.237348, ewa inertia: 0.291840
# [MiniBatchKMeans] Reassigning 50 cluster centers.
# Minibatch iteration 100/669000: mean batch inertia: 0.234243, ewa inertia: 0.291823
# Minibatch iteration 101/669000: mean batch inertia: 0.202675, ewa inertia: 0.291796
# Minibatch iteration 102/669000: mean batch inertia: 0.244441, ewa inertia: 0.291782
# Minibatch iteration 103/669000: mean batch inertia: 0.328429, ewa inertia: 0.291793
# Minibatch iteration 104/669000: mean batch inertia: 0.218924, ewa inertia: 0.291771
# Minibatch iteration 105/669000: mean batch inertia: 0.306330, ewa inertia: 0.291776
# Minibatch iteration 106/669000: mean batch inertia: 0.241676, ewa inertia: 0.291761
# Minibatch iteration 107/669000: mean batch inertia: 0.243010, ewa inertia: 0.291746
# Minibatch iteration 108/669000: mean batch inertia: 0.310240, ewa inertia: 0.291752
# Minibatch iteration 109/669000: mean batch inertia: 0.234517, ewa inertia: 0.291735
# [MiniBatchKMeans] Reassigning 50 cluster centers.
# Minibatch iteration 110/669000: mean batch inertia: 0.250920, ewa inertia: 0.291722
# Minibatch iteration 111/669000: mean batch inertia: 0.285169, ewa inertia: 0.291720
# Minibatch iteration 112/669000: mean batch inertia: 0.345138, ewa inertia: 0.291736
# Minibatch iteration 113/669000: mean batch inertia: 0.202154, ewa inertia: 0.291710
# Minibatch iteration 114/669000: mean batch inertia: 0.171830, ewa inertia: 0.291674
# Minibatch iteration 115/669000: mean batch inertia: 0.179931, ewa inertia: 0.291640
# Minibatch iteration 116/669000: mean batch inertia: 0.124725, ewa inertia: 0.291591
# Minibatch iteration 117/669000: mean batch inertia: 0.247935, ewa inertia: 0.291577
# Minibatch iteration 118/669000: mean batch inertia: 0.351016, ewa inertia: 0.291595
# Minibatch iteration 119/669000: mean batch inertia: 0.230297, ewa inertia: 0.291577
# [MiniBatchKMeans] Reassigning 50 cluster centers.
# Minibatch iteration 120/669000: mean batch inertia: 0.298146, ewa inertia: 0.291579
# Minibatch iteration 121/669000: mean batch inertia: 0.244933, ewa inertia: 0.291565
# Minibatch iteration 122/669000: mean batch inertia: 0.183566, ewa inertia: 0.291533
# Minibatch iteration 123/669000: mean batch inertia: 0.316206, ewa inertia: 0.291540
# Minibatch iteration 124/669000: mean batch inertia: 0.145821, ewa inertia: 0.291496
# Minibatch iteration 125/669000: mean batch inertia: 0.188446, ewa inertia: 0.291466
# Minibatch iteration 126/669000: mean batch inertia: 0.220649, ewa inertia: 0.291444
# Minibatch iteration 127/669000: mean batch inertia: 0.244572, ewa inertia: 0.291430
# Minibatch iteration 128/669000: mean batch inertia: 0.175880, ewa inertia: 0.291396
# Minibatch iteration 129/669000: mean batch inertia: 0.527520, ewa inertia: 0.291467
# [MiniBatchKMeans] Reassigning 50 cluster centers.
# Minibatch iteration 130/669000: mean batch inertia: 0.230276, ewa inertia: 0.291448
# Minibatch iteration 131/669000: mean batch inertia: 0.271512, ewa inertia: 0.291442
# Minibatch iteration 132/669000: mean batch inertia: 0.207546, ewa inertia: 0.291417
# Minibatch iteration 133/669000: mean batch inertia: 0.168427, ewa inertia: 0.291380
# Minibatch iteration 134/669000: mean batch inertia: 0.141526, ewa inertia: 0.291336
# Minibatch iteration 135/669000: mean batch inertia: 0.253759, ewa inertia: 0.291324
# Minibatch iteration 136/669000: mean batch inertia: 0.165134, ewa inertia: 0.291287
# Minibatch iteration 137/669000: mean batch inertia: 0.224687, ewa inertia: 0.291267
# Minibatch iteration 138/669000: mean batch inertia: 0.254364, ewa inertia: 0.291256
# Minibatch iteration 139/669000: mean batch inertia: 0.244575, ewa inertia: 0.291242
# [MiniBatchKMeans] Reassigning 50 cluster centers.
# Minibatch iteration 140/669000: mean batch inertia: 0.175321, ewa inertia: 0.291207
# Minibatch iteration 141/669000: mean batch inertia: 0.333388, ewa inertia: 0.291220
# Minibatch iteration 142/669000: mean batch inertia: 0.375326, ewa inertia: 0.291245
# Minibatch iteration 143/669000: mean batch inertia: 0.239087, ewa inertia: 0.291229
# Minibatch iteration 144/669000: mean batch inertia: 0.257973, ewa inertia: 0.291219
# Minibatch iteration 145/669000: mean batch inertia: 0.166368, ewa inertia: 0.291182
# Minibatch iteration 146/669000: mean batch inertia: 0.193186, ewa inertia: 0.291153
# Minibatch iteration 147/669000: mean batch inertia: 0.246702, ewa inertia: 0.291139
# Minibatch iteration 148/669000: mean batch inertia: 0.219907, ewa inertia: 0.291118
# Minibatch iteration 149/669000: mean batch inertia: 0.273889, ewa inertia: 0.291113
# [MiniBatchKMeans] Reassigning 50 cluster centers.
# Minibatch iteration 150/669000: mean batch inertia: 0.355454, ewa inertia: 0.291132
# Minibatch iteration 151/669000: mean batch inertia: 0.181572, ewa inertia: 0.291099
# Minibatch iteration 152/669000: mean batch inertia: 0.158655, ewa inertia: 0.291060
# Minibatch iteration 153/669000: mean batch inertia: 0.245468, ewa inertia: 0.291046
# Minibatch iteration 154/669000: mean batch inertia: 0.225612, ewa inertia: 0.291027
# Minibatch iteration 155/669000: mean batch inertia: 0.216437, ewa inertia: 0.291004
# Minibatch iteration 156/669000: mean batch inertia: 0.212767, ewa inertia: 0.290981
# Minibatch iteration 157/669000: mean batch inertia: 0.992853, ewa inertia: 0.291191
# Minibatch iteration 158/669000: mean batch inertia: 0.122097, ewa inertia: 0.291140
# Minibatch iteration 159/669000: mean batch inertia: 0.199198, ewa inertia: 0.291113
# [MiniBatchKMeans] Reassigning 50 cluster centers.
# Minibatch iteration 160/669000: mean batch inertia: 0.258847, ewa inertia: 0.291103
# Minibatch iteration 161/669000: mean batch inertia: 0.170058, ewa inertia: 0.291067
# Minibatch iteration 162/669000: mean batch inertia: 0.248902, ewa inertia: 0.291054
# Minibatch iteration 163/669000: mean batch inertia: 0.239589, ewa inertia: 0.291039
# Minibatch iteration 164/669000: mean batch inertia: 0.231998, ewa inertia: 0.291021
# Minibatch iteration 165/669000: mean batch inertia: 0.249391, ewa inertia: 0.291009
# Minibatch iteration 166/669000: mean batch inertia: 0.198153, ewa inertia: 0.290981
# Converged (lack of improvement in inertia) at iteration 166/669000
# Computing label assignment and total inertia
# Computing label assignment and total inertia
# Init 1/3 with method: k-means++
# /home/simi/anaconda3/lib/python3.7/site-packages/sklearn/cluster/k_means_.py:1559: RuntimeWarning: init_size=300 should be larger than k=4000. Setting it to 3*k
#   init_size=init_size)
# Inertia for init 1/3: 10.047744
# Init 2/3 with method: k-means++
# /home/simi/anaconda3/lib/python3.7/site-packages/sklearn/cluster/k_means_.py:1559: RuntimeWarning: init_size=300 should be larger than k=4000. Setting it to 3*k
#   init_size=init_size)
# Inertia for init 2/3: 11.270468
# Init 3/3 with method: k-means++
# /home/simi/anaconda3/lib/python3.7/site-packages/sklearn/cluster/k_means_.py:1559: RuntimeWarning: init_size=300 should be larger than k=4000. Setting it to 3*k
#   init_size=init_size)
# Inertia for init 3/3: 9.887581
# Minibatch iteration 1/750000: mean batch inertia: 1.174098, ewa inertia: 1.174098
# Minibatch iteration 2/750000: mean batch inertia: 1.047768, ewa inertia: 1.174065
# Minibatch iteration 3/750000: mean batch inertia: 1.132530, ewa inertia: 1.174054
# Minibatch iteration 4/750000: mean batch inertia: 1.334162, ewa inertia: 1.174096
# Minibatch iteration 5/750000: mean batch inertia: 1.243821, ewa inertia: 1.174115
# Minibatch iteration 6/750000: mean batch inertia: 1.155640, ewa inertia: 1.174110
# Minibatch iteration 7/750000: mean batch inertia: 1.409201, ewa inertia: 1.174173
# Minibatch iteration 8/750000: mean batch inertia: 1.097770, ewa inertia: 1.174152
# Minibatch iteration 9/750000: mean batch inertia: 1.259398, ewa inertia: 1.174175
# [MiniBatchKMeans] Reassigning 50 cluster centers.
# Minibatch iteration 10/750000: mean batch inertia: 1.230220, ewa inertia: 1.174190
# Minibatch iteration 11/750000: mean batch inertia: 1.130351, ewa inertia: 1.174178
# Minibatch iteration 12/750000: mean batch inertia: 1.076219, ewa inertia: 1.174152
# Minibatch iteration 13/750000: mean batch inertia: 0.879589, ewa inertia: 1.174074
# Converged (lack of improvement in inertia) at iteration 13/750000
# Computing label assignment and total inertia
# Computing label assignment and total inertia

# %%
h1 = np.bincount(lbl1, minlength=N)
h2 = np.bincount(lbl2, minlength=N)

plt.bar(np.arange(N), h1)
plt.show()
plt.bar(np.arange(N), h2)
plt.show()

# %%
# Step 4 Calculating transformation between histograms
from pyemd import emd_with_flow

# a) Calculate the difference between the colors to define dij
distance_matrix = np.zeros((N,N), dtype=np.float64)

#for i in range(N):
#    for j in range(N):
#        d = cookbook1[i, :] - cookbook2[j,:]
#        distance_matrix[i,j] = np.dot(d.T, d)
        
distance_matrix = cookbook1 - cookbook2
distance_matrix = np.dot(distance_matrix, distance_matrix.T)
# b) Calculate earth mover distance
h_1 = h1 / h1.sum()
h_2 = h2 / h2.sum()
val, min_cost = emd_with_flow(h_1.astype(np.float64), h_2.astype(np.float64), distance_matrix)    
print(val)

min_cost = np.array(min_cost)

# %%
# sample from the earth movers distance a color so that we can transform back to an image
print(sum(min_cost[0]), h1[0])
w, h = lbl_img_1.shape

transformed_img = np.zeros((w,h,3))

for i in range(w):
    for j in range(h):
        source_index = lbl_img_1[i][j]
        sample_target_index = np.argmax(np.random.multinomial(1, min_cost[source_index]
                                                              /sum(min_cost[source_index]), size=1))
        transformed_img[i][j] = cookbook2[sample_target_index,:]

# %%
plt.figure(2)
plt.clf()
plt.axis('off')
plt.title('Original Image')
plt.imshow(skimage.color.lab2rgb(im2_lab))
plt.show()

plt.figure(2)
plt.clf()
plt.axis('off')
plt.title('Transformed Image')
plt.imshow(skimage.color.lab2rgb(transformed_img))
plt.show()
